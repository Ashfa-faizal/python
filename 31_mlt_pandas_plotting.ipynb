# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('data_jobs.csv')

# %%
df['job_posted_date'] = pd.to_datetime(df["job_posted_date"])

# %% [markdown]
# #plotting a series by using pandas

# %%
job_count = df.job_title_short.value_counts()

# %%
job_count.plot(kind='bar')
plt.title("posting by job title")
plt.xlabel("")    # removing a lable
plt.ylabel("count of job postings")
plt.xticks(rotation=45, ha="right")
plt.show()

# %% [markdown]
# #plotting a dataframe

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
# how are the salaries trending over in 2023

# %%
# selecting what column need to plot
df[['job_posted_date', 'salary_year_avg']].dropna(subset=['salary_year_avg'])
# Out:
#           job_posted_date  salary_year_avg
# 28    2023-08-01 13:37:57    109500.000000
# 77    2023-06-26 14:22:54    140000.000000
# 92    2023-02-21 13:29:59    120000.000000
# 100   2023-07-31 13:01:18    228222.000000
# 109   2023-10-12 13:02:19     89000.000000
# ...                   ...              ...
# 13880 2023-06-21 14:01:57    137533.703125
# 13909 2023-10-13 13:03:19    140000.000000
# 13913 2023-01-30 13:24:10     89100.000000
# 13916 2023-07-10 13:00:32     68000.000000
# 13931 2023-08-07 13:01:08    115000.000000
#
# [465 rows x 2 columns]

# %%
df.plot(x='job_posted_date', y='salary_year_avg', kind='line')
plt.show()

# %%
# it's so mess , with 700000 datas to plot ,there are so much noises in here
# or we can do plot with months
