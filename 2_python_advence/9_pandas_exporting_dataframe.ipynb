# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv(r"C:\Users\HP\Desktop\ASHFA\data_jobs.csv")

# Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
# in data analyst job
df_DA = df[(df['job_title_short'] == 'Data Analyst')].copy()
df_DA['job_posted_month'] = df_DA['job_posted_date'].dt.strftime('%b')

months = df_DA['job_posted_month'].unique()
df_DA_month = {}
for month in months:
    df_DA_month[month] = df_DA[df_DA['job_posted_month'] == month].copy()

# %%
df_q1 = pd.concat([df_DA_month['Jan'],df_DA_month['Feb'],df_DA_month['Mar']],ignore_index=True)
df_q1
# Out:
#       job_title_short                                          job_title  \
# 0        Data Analyst                                       Data Analyst
# 1        Data Analyst                               Data Analyst (m/f/d)
# 2        Data Analyst                                       Data Analyst
# 3        Data Analyst    Projects & Solutions Data Analyst (UK Pensions)
# 4        Data Analyst  Data Base work from home job/internship at Mga...
# ...               ...                                                ...
# 56381    Data Analyst                   Oracle Supply Chain Data Analyst
# 56382    Data Analyst                               Data Analyst (m/w/d)
# 56383    Data Analyst  Amul Careers 2023 - Apply Online - Data Analys...
# 56384    Data Analyst                 Data & Analytics Architect (w/m/x)
# 56385    Data Analyst                                   CRM Data Analyst
#
#                                  job_location  \
# ...

# %% [markdown]
# # to_clipboard

# %%
df_q1.head().to_clipboard(sep=',')  # sep , means whenever u copy this put commas in between each of these values
# after running this shell just cntrl+v to past in markdown shell

# %% [markdown]
# ,job_title_short,job_title,job_location,job_via,job_schedule_type,job_work_from_home,search_location,job_posted_date,job_no_degree_mention,job_health_insurance,job_country,salary_rate,salary_year_avg,salary_hour_avg,company_name,job_skills,job_type_skills,job_posted_month
# 0,Data Analyst,Data Analyst,"Guadalajara, Jalisco, Mexico",via BeBee México,Full-time,False,Mexico,2023-01-14 13:18:07,False,False,Mexico,,,,Hewlett Packard Enterprise,"['r', 'python', 'sql', 'nosql', 'power bi', 'tableau']","{'analyst_tools': ['power bi', 'tableau'], 'programming': ['r', 'python', 'sql', 'nosql']}",Jan
# 1,Data Scientist,Data Scientist,"Zaventem, Belgium",via BeBee Belgique,Full-time,False,Belgium,2023-01-31 13:53:38,False,False,Belgium,,,,Devoteam,"['r', 'python', 'sql', 'pandas', 'numpy', 'scikit-learn', 'matplotlib', 'hadoop', 'spark']","{'libraries': ['pandas', 'numpy', 'scikit-learn', 'matplotlib', 'hadoop', 'spark'], 'programming': ['r', 'python', 'sql']}",Jan
# 2,Data Engineer,Data Engineer,"Fort Worth, TX",via LinkedIn,Full-time,False,"Texas, United States",2023-01-25 13:24:01,False,False,United States,,,,Programmers.io,"['sql', 'python']","{'programming': ['sql', 'python']}",Jan
# 3,Data Engineer,Data Engineer,"San Mateo, CA",via LinkedIn,Full-time,False,"California, United States",2023-01-28 13:07:30,False,True,United States,,,,Verkada,"['sql', 'python', 'aws', 'looker']","{'analyst_tools': ['looker'], 'cloud': ['aws'], 'programming': ['sql', 'python']}",Jan
# 4,Data Scientist,Data Scientist,"São Paulo, State of São Paulo, Brazil",via BeBee,Full-time,False,Brazil,2023-01-03 23:02:27,False,False,Brazil,,,,Mars,"['python', 'sql', 'azure']","{'cloud': ['azure'], 'programming': ['python', 'sql']}",Jan

# %% [markdown]
# # to_csv()

# %%
df_q1.to_csv("quarter_1.csv")   # specify file name and file extention

# %%
# it'll autometically saved in our project . to read that csv file
pd.read_csv("quarter_1.csv").head(3)
# Out:
#    Unnamed: 0 job_title_short       job_title                  job_location  \
# 0           0    Data Analyst    Data Analyst  Guadalajara, Jalisco, Mexico
# 1           1  Data Scientist  Data Scientist             Zaventem, Belgium
# 2           2   Data Engineer   Data Engineer                Fort Worth, TX
#
#               job_via job_schedule_type  job_work_from_home  \
# 0    via BeBee México         Full-time               False
# 1  via BeBee Belgique         Full-time               False
# 2        via LinkedIn         Full-time               False
#
#         search_location      job_posted_date  job_no_degree_mention  \
# 0                Mexico  2023-01-14 13:18:07                  False
# 1               Belgium  2023-01-31 13:53:38                  False
# 2  Texas, United States  2023-01-25 13:24:01                  False
#
#    job_health_insurance    job_country salary_rate  salary_year_avg  \
# 0                 False         Mexico         NaN              NaN
# ...

# %%
# to remove unnamed column
pd.read_csv("quarter_1.csv", index_col = 0 ).head(3)
# Out:
#   job_title_short       job_title                  job_location  \
# 0    Data Analyst    Data Analyst  Guadalajara, Jalisco, Mexico
# 1  Data Scientist  Data Scientist             Zaventem, Belgium
# 2   Data Engineer   Data Engineer                Fort Worth, TX
#
#               job_via job_schedule_type  job_work_from_home  \
# 0    via BeBee México         Full-time               False
# 1  via BeBee Belgique         Full-time               False
# 2        via LinkedIn         Full-time               False
#
#         search_location      job_posted_date  job_no_degree_mention  \
# 0                Mexico  2023-01-14 13:18:07                  False
# 1               Belgium  2023-01-31 13:53:38                  False
# 2  Texas, United States  2023-01-25 13:24:01                  False
#
#    job_health_insurance    job_country salary_rate  salary_year_avg  \
# 0                 False         Mexico         NaN              NaN
# ...

# %% [markdown]
# # to excel()

# %%
df_q1.to_excel('quarter_1.xlsx')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 df_q1.to_excel('quarter_1.xlsx')
#
# File c:\Users\HP\anaconda3\envs\python_course\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File c:\Users\HP\anaconda3\envs\python_course\Lib\site-packages\pandas\core\generic.py:2417, in NDFrame.to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, inf_rep, freeze_panes, storage_options, engine_kwargs)
# ...

# %%
# basically we need the python to excel  module to do this
# so install excel
# in terminal ( open by pressing cntrl + tilda[``]={key before 1 } )
# run conda install openpyxl ( make sure we are in correct environment )

# %%
df_q1.to_excel('quarter_1.xlsx')

# %%
# excel has million row limit

# %% [markdown]
# # to_sql()

# %% [markdown]
# * sql method not much usage , to know more get help chat gpt

# %%
from sqlalchemy import create_engine
engine  = create_engine('sqlite:///jobs.db')

df_q1.to_sql('job_table', con=engine , if_exist='append', index= False)

# %% [markdown]
# # to_parquet()

# %% [markdown]
# * parquet and pickle are gonna save our time if we are dealing with large data set to export them and load them into python very quickly
# * we can read our data lot quicker by using these method, sometimes more quickly than csv

# %%
df.to_parquet('jobs_data.parquet')

# %% [markdown]
# # to_pickle()

# %%
df.to_pickle('job_data.pkl')

# %%
df_loaded = pd.read_pickle('job_data.pkl')
df_loaded
