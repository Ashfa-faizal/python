# %%
import pandas as pd
import matplotlib.pyplot as plt
import ast

df = pd.read_csv(r"C:\Users\HP\Desktop\ASHFA\data_jobs.csv")

# Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])
df['job_skills'] = df['job_skills'].apply(lambda x: ast.literal_eval(x) if pd.notna(x) else x)

# %%
df_DA_US = df[(df['job_title_short'] == 'Data Analyst') & (df['job_country'] == 'United States')].copy()
df_DA_US = df_DA_US['job_location'].value_counts().head(10).to_frame()   # changing into dataframe
df_DA_US
# Out:
#                  count
# job_location
# Anywhere          5106
# New York, NY      3035
# Atlanta, GA       2741
# Chicago, IL       2337
# Austin, TX        1919
# Dallas, TX        1862
# Washington, DC    1592
# Charlotte, NC     1433
# Tampa, FL         1431
# Los Angeles, CA   1328

# %%
import seaborn as sns

sns.set_theme(style='ticks')
sns.barplot(data=df_DA_US, x='count', y='job_location', hue='count', palette='dark:b_r', legend=False)
sns.despine()  # it'll remove border around the graph
plt.title('Counts of Job Locations for Data Analyst in the US')
plt.xlabel('Number of Jobs')
plt.ylabel('')
plt.show()

# %%
df_DA_US = df[(df['job_title_short'] == 'Data Analyst') & (df['job_country'] == 'United States')].copy()

# %%
fig,ax = plt.subplots(1,3 , figsize=(10,3))

dict_column = {
    'job_work_from_home': 'Work from Home Offered',
    'job_no_degree_mention': 'Degree Requirement',
    'job_health_insurance': 'Health Insurance Offered'
}

for i,(column,title) in enumerate(dict_column.items()):
    ax[i].pie(df_DA_US[column].value_counts(), startangle=90, autopct='%1.1f%%',labels=['False','True'])
    ax[i].set_title(title)

# %%
# to select same word in different rows press ' cnt+shift+l '

# %%
df_DA_US = df_DA_US['company_name'].value_counts().head(10).to_frame()   # changing into dataframe

import seaborn as sns

sns.set_theme(style='ticks')
sns.barplot(data=df_DA_US, x='count', y='company_name', hue='count', palette='dark:b_r', legend=False)
sns.despine()  # it'll remove border around the graph
plt.title('Counts of companies for Data Analyst in the US')
plt.xlabel('Number of Jobs')
plt.ylabel('')
plt.show()
