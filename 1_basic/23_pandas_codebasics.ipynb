# %%
import pandas as pd

# %%
weather_date = {
    'day': ['1/1/2017','1/2/2017','1/3/2017','1/4/2017','1/5/2017','1/6/2017'],
    'temperature': [32,23,34,35,23,31],
    'windspeed': [6,7,7,8,9,4],
    'event': ['Rain','sunny','snow','snow','rain','rain']
}
df = pd.DataFrame(weather_date)
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           23          7  sunny
# 2  1/3/2017           34          7   snow
# 3  1/4/2017           35          8   snow
# 4  1/5/2017           23          9   rain
# 5  1/6/2017           31          4   rain

# %%
rows, columns = df.shape

# %%
rows
# Out:
# 6

# %%
columns
# Out:
# 4

# %%
df.head(1)
# Out:
#         day  temperature  windspeed event
# 0  1/1/2017           32          6  Rain

# %%
df.tail(1)
# Out:
#         day  temperature  windspeed event
# 5  1/6/2017           31          4  rain

# %%
df[2:5]
# Out:
#         day  temperature  windspeed event
# 2  1/3/2017           34          7  snow
# 3  1/4/2017           35          8  snow
# 4  1/5/2017           23          9  rain

# %%
# print column
df.columns
# Out:
# Index(['day', 'temperature', 'windspeed', 'event'], dtype='object')

# %%
df.day # or df['day']
# Out:
# 0    1/1/2017
# 1    1/2/2017
# 2    1/3/2017
# 3    1/4/2017
# 4    1/5/2017
# 5    1/6/2017
# Name: day, dtype: object

# %%
# print specific columns
df[['event','day']]
# Out:
#    event       day
# 0   Rain  1/1/2017
# 1  sunny  1/2/2017
# 2   snow  1/3/2017
# 3   snow  1/4/2017
# 4   rain  1/5/2017
# 5   rain  1/6/2017

# %%
df['temperature'].max()
# Out:
# 35

# %%
df.describe()
# Out:
#        temperature  windspeed
# count     6.000000   6.000000
# mean     29.666667   6.833333
# std       5.354126   1.722401
# min      23.000000   4.000000
# 25%      25.000000   6.250000
# 50%      31.500000   7.000000
# 75%      33.500000   7.750000
# max      35.000000   9.000000

# %%
df[df.temperature >= 32]
# Out:
#         day  temperature  windspeed event
# 0  1/1/2017           32          6  Rain
# 2  1/3/2017           34          7  snow
# 3  1/4/2017           35          8  snow

# %%
df[df.temperature == df.temperature.max()]    # or if my header have a spaces df[df.temperature == df['temperature'].max()]
# Out:
#         day  temperature  windspeed event
# 3  1/4/2017           35          8  snow

# %%
df[['day','temperature']][df.temperature == df['temperature'].max()]
# Out:
#         day  temperature
# 3  1/4/2017           35

# %% [markdown]
# # set index

# %%
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           23          7  sunny
# 2  1/3/2017           34          7   snow
# 3  1/4/2017           35          8   snow
# 4  1/5/2017           23          9   rain
# 5  1/6/2017           31          4   rain

# %%
df.set_index('day', inplace=True)      # inplace will modify original one
df
# Out:
#           temperature  windspeed  event
# day
# 1/1/2017           32          6   Rain
# 1/2/2017           23          7  sunny
# 1/3/2017           34          7   snow
# 1/4/2017           35          8   snow
# 1/5/2017           23          9   rain
# 1/6/2017           31          4   rain

# %%
df.loc['1/2/2017']
# Out:
# temperature       23
# windspeed          7
# event          sunny
# Name: 1/2/2017, dtype: object

# %%
# to return our original df
df.reset_index(inplace=True)
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           23          7  sunny
# 2  1/3/2017           34          7   snow
# 3  1/4/2017           35          8   snow
# 4  1/5/2017           23          9   rain
# 5  1/6/2017           31          4   rain

# %%
df.set_index('event', inplace=True)
df
# Out:
#             day  temperature  windspeed
# event
# Rain   1/1/2017           32          6
# sunny  1/2/2017           23          7
# snow   1/3/2017           34          7
# snow   1/4/2017           35          8
# rain   1/5/2017           23          9
# rain   1/6/2017           31          4

# %%
df.loc['snow']
# Out:
#             day  temperature  windspeed
# event
# snow   1/3/2017           34          7
# snow   1/4/2017           35          8
