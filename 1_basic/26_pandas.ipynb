# %%
# !pip list
# Out:
# Package                               Version
# ------------------------------------- -------------------
# absl-py                               1.4.0
# accelerate                            1.6.0
# aiohappyeyeballs                      2.6.1
# aiohttp                               3.11.15
# aiosignal                             1.3.2
# alabaster                             1.0.0
# albucore                              0.0.24
# albumentations                        2.0.6
# ale-py                                0.11.0
# altair                                5.5.0
# annotated-types                       0.7.0
# antlr4-python3-runtime                4.9.3
# anyio                                 4.9.0
# argon2-cffi                           23.1.0
# argon2-cffi-bindings                  21.2.0
# array_record                          0.7.2
# arviz                                 0.21.0
# astropy                               7.0.2
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/sample_data/california_housing_test.csv")

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# ...

# %%
#Can be thought of as a dict-like container for Series objects

# %%
# let's access total room
df["total_rooms"]
# Out:
# 0       3885.0
# 1       1510.0
# 2       3589.0
# 3         67.0
# 4       1241.0
#          ...
# 2995    1450.0
# 2996    5257.0
# 2997     956.0
# 2998      96.0
# 2999    1765.0
# Name: total_rooms, Length: 3000, dtype: float64

# %%
# or we can do
df.total_bedrooms
# Out:
# 0        661.0
# 1        310.0
# 2        507.0
# 3         15.0
# 4        244.0
#          ...
# 2995     642.0
# 2996    1082.0
# 2997     201.0
# 2998      14.0
# 2999     263.0
# Name: total_bedrooms, Length: 3000, dtype: float64

# %%
# access 1st item in total bedrooms
df.total_bedrooms[0]
# Out:
# np.float64(661.0)

# %%
df['total_bedrooms'][2999]
# Out:
# np.float64(263.0)

# %%
# 1. https://huggingface.co/datasets/lukebarousse/data_jobs ----> file&versions ----> csv ---> dowload ---> upload to notebook
# 2. by load dataset function which allows to provide the name of our data set & load

# %%
# 1 way to upload data file
#!pip install datasets
# from datasets import load_dataset
# dataset = load_dataset('lukebarousse/data_jobs')

# %% [markdown]
# #data_jobs file

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/data_jobs.csv")
# Out:
# <ipython-input-5-1cd17c9ff355>:1: DtypeWarning: Columns (5,8,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("/content/data_jobs.csv")

# %% [markdown]
# #access different columns and rows

# %%
#df.head(2)                  give me first 2 rows
#df.tail(4)                  give me last 4 rows
#df['job_title_short']        give me this spesific column
#df[['job_title_short','job_location']]        making list to provide multiple different column

# %%
# to view 92 - 100 rows, we are using iloc method
#df.iloc[90:93,0:2]     from 90 - 93 rows print first 2 columns   or we can do
#df[['job_title_short','job_location']].iloc[90:100]

# %% [markdown]
# #methods

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35543 entries, 0 to 35542
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   job_title_short        35543 non-null  object
#  1   job_title              35543 non-null  object
#  2   job_location           35492 non-null  object
#  3   job_via                35541 non-null  object
#  4   job_schedule_type      34932 non-null  object
#  5   job_work_from_home     35543 non-null  object
#  6   search_location        35542 non-null  object
#  7   job_posted_date        35542 non-null  object
#  8   job_no_degree_mention  35542 non-null  object
#  9   job_health_insurance   35542 non-null  object
#  10  job_country            35538 non-null  object
#  11  salary_rate            1422 non-null   object
#  12  salary_year_avg        1025 non-null   float64
#  13  salary_hour_avg        381 non-null    float64
# ...

# %%
len(df)
# Out:
# 35543

# %%
df.shape
# Out:
# (35543, 17)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=35543, step=1)

# %%
df.columns
# Out:
# Index(['job_title_short', 'job_title', 'job_location', 'job_via',
#        'job_schedule_type', 'job_work_from_home', 'search_location',
#        'job_posted_date', 'job_no_degree_mention', 'job_health_insurance',
#        'job_country', 'salary_rate', 'salary_year_avg', 'salary_hour_avg',
#        'company_name', 'job_skills', 'job_type_skills'],
#       dtype='object')

# %%
df.count()
# Out:
# job_title_short          35543
# job_title                35543
# job_location             35492
# job_via                  35541
# job_schedule_type        34932
# job_work_from_home       35543
# search_location          35542
# job_posted_date          35542
# job_no_degree_mention    35542
# job_health_insurance     35542
# job_country              35538
# salary_rate               1422
# salary_year_avg           1025
# salary_hour_avg            381
# company_name             35541
# job_skills               30728
# job_type_skills          30728
# dtype: int64

# %%
df.describe()      # it'll discribe only neumerical column
# Out:
#        salary_year_avg  salary_hour_avg
# count      1025.000000       381.000000
# mean     126783.371772        50.113084
# std       49325.274717        21.971638
# min       30750.000000         8.500000
# 25%       90000.000000        31.500000
# 50%      120000.000000        50.889999
# 75%      151000.000000        65.000000
# max      375000.000000       130.000000

# %%
# to get only uniqe value in job title short
df.job_title_short.unique()       # or  df['job_title_short'].unique()
# Out:
# array(['Senior Data Engineer', 'Data Analyst', 'Data Engineer',
#        'Business Analyst', 'Data Scientist', 'Machine Learning Engineer',
#        'Senior Data Analyst', 'Cloud Engineer', 'Senior Data Scientist',
#        'Software Engineer'], dtype=object)

# %%
# using comparison operator to specifically identify certain job titles
#df.job_title_short == 'Data Analyst'      it'll give me a boolean
df[df.job_title_short == 'Data Analyst']    # df will filter for this condition
# Out:
#       job_title_short                                          job_title  \
# 1        Data Analyst                                       Data Analyst
# 12       Data Analyst        Stagiaire Data Analyst (H/F) - Lyon (69006)
# 18       Data Analyst                                       Data Analyst
# 31       Data Analyst                           Stage - Data Analyst F/H
# 34       Data Analyst  Data Analyst als Marketing Manager Automation ...
# ...               ...                                                ...
# 35514    Data Analyst                                       Data Analyst
# 35517    Data Analyst                               Data Analyst (w/m/d)
# 35531    Data Analyst         Entry-Level Compliance Data Analyst - Temp
# 35534    Data Analyst                              Research Data Analyst
# 35537    Data Analyst                                 Data-Analyst - H/F
#
#                        job_location                          job_via  \
# ...

# %%
df[(df.job_title_short == 'Data Analyst') & (df['salary_year_avg'] > 100000)]
# in here if we want any of these one want to be correct then use "or (|) " condition
# Out:
#       job_title_short                                      job_title  \
# 410      Data Analyst    IT Business Lead Data Analyst - VP - Hybrid
# 1555     Data Analyst                  Data Analyst/Engineer (M/F/D)
# 1681     Data Analyst                                   Data Analyst
# 1684     Data Analyst                       Data Analyst - Data17829
# 1867     Data Analyst  Data Integration Analyst (West Coast/Chicago)
# ...               ...                                            ...
# 33182    Data Analyst          Data Analyst, Field Reliability Group
# 33362    Data Analyst                    Data Analyst - Analyst12277
# 33899    Data Analyst                               Sr. Data Analyst
# 34607    Data Analyst                        Data Analyst (ID#10252)
# 34647    Data Analyst          Data Analyst & Visualization Engineer
#
#              job_location               job_via job_schedule_type  \
# 410    Atlantic Beach, FL  via ComputerJobs.com         Full-time
# ...

# %%
# running data analyst job with which have salaries
df[(df.job_title_short == 'Data Analyst') & (df.salary_year_avg.notna())] [['job_title_short','salary_year_avg']]
# Out:
#       job_title_short  salary_year_avg
# 109      Data Analyst          89000.0
# 180      Data Analyst          90250.0
# 410      Data Analyst         133285.0
# 988      Data Analyst          62623.0
# 1413     Data Analyst          71300.0
# ...               ...              ...
# 33926    Data Analyst          63579.0
# 34083    Data Analyst          75000.0
# 34473    Data Analyst          90000.0
# 34607    Data Analyst         110000.0
# 34647    Data Analyst         145500.0
#
# [233 rows x 2 columns]
