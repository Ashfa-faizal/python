# %%
#Graph the average salary (salary_year_avg) by job_title_short as a horizontal bar chart.
# Order it from the highest salary to the lowest. Include a title, and labels for the x & y-axis.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/content/data_jobs.csv")

# %%
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
job_salary = df.groupby("job_title_short")['salary_year_avg'].median().sort_values()

# %%
# Plot the chart
job_salary.plot(kind='barh')

# Customize the chart
plt.xlabel('Salary ($USD)')
plt.ylabel('')
plt.title('Median Salary by Job Title')

# Show the bar chart
plt.show()

# %%
x = 'AAABBBBCCCC1111'
